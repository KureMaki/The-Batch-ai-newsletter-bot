# %%
# 🤖 The Batch Newsletter Summarizer with OpenAI (Jupyter Ready)

# === 第 1 步：导入依赖 ===
from newsletter_tool import fetch_newsletter_text, gpt_summary_and_translation, save_to_notion
from IPython.display import Markdown, display

def display_markdown_block(text):
    display(Markdown(f"""
---


{text}


---
"""))

# %%
# === 第 2 步：你的 OpenAI API Key ===
from dotenv import load_dotenv
load_dotenv()
print("环境变量已加载，API 客户端将在首次调用时初始化。")

# %%
# === 第 3 步：抓取函数 ===
# 已从 newsletter_tool 导入 fetch_newsletter_text
pass

# %%
# 示例：抓取第 323 期
url = "https://www.deeplearning.ai/the-batch/issue-322/"
full_text = fetch_newsletter_text(url)
print(full_text[:1000]) # 预览前1000字符

# %%
# === 第 4 步：用 OpenAI 执行摘要 + 翻译 ===
# 已从 newsletter_tool 导入 gpt_summary_and_translation
pass

# %%
# === 第 5 步：运行生成摘要与翻译 ===
summary_result = gpt_summary_and_translation(full_text)

# %%
# === 第 6 步：Markdown 输出美化 ===
# display_markdown_block 已在第 1 步定义
print("✅ 摘要生成完毕，开始显示：")
display_markdown_block(summary_result)

# %%
# === 第 7 步：保存到 Notion（结构化）===
# 已从 newsletter_tool 导入 save_to_notion
pass

# %%
# 调用写入
save_to_notion(summary_result,url)
print("✅ 内容已保存至 Notion！")
